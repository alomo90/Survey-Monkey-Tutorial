# %%
import pandas as pd
import os

# %%
pwd = os.getcwd()

# %%
dataset = pd.read_excel(pwd + '/2023 DEI Survey - Edited.xlsx', sheet_name='Edited_Data')
dataset
# Out:
#      Respondent ID  Collector ID    Start Date      End Date      IP Address  \
# 0     114254911214     424609639  44982.604132  44982.608380    174.209.41.5
# 1     114254784991     424609561  44982.392211  44982.394120    50.47.84.103
# 2     114254561357     424609639  44981.985521  44981.999062  108.197.66.112
# 3     114254177232     424609639  44981.544699  44981.548125  44.232.201.254
# 4     114253615503     424609561  44980.941007  44980.942616   216.195.4.101
# ..             ...           ...           ...           ...             ...
# 710   114239075355     424609561  44964.377975  44964.381123   173.12.119.74
# 711   114239072831     424609561  44964.376366  44964.380694    74.129.41.54
# 712   114239074004     424609561  44964.376100  44964.378368  50.247.195.142
# 713   114239073171     424609561  44964.376076  44964.378287   100.38.84.227
# 714   114239073402     424609561  44964.377211  44964.377731  216.74.243.186
#
#                        Email Address     First Name  Last Name  IREM ID  \
# 0        CharisseStewart28@gmail.com       Charisse    Stewart  6316678
# 1          robertbalaceanu@gmail.com  Iulian Robert  Balaceanu  6195193
# 2             Crystalstude@yahoo.com        Crystal      Stude  6163848
# 3          bmchenry@riverrockreg.com        Brianna    McHenry   244729
# 4               sarah.berry@live.com          Sarah      Berry  6192377
# ..                               ...            ...        ...      ...
# 710          afortini@tedglasrud.com          Angel    Fortini  6354446
# 711  delawaretracemanager@pedcor.net       Jonathan    Kilgore  6254034
# 712         charvey@corcoranmgmt.com       Caroline     Harvey  6303253
# 713           rcolburn@reliantrs.com        Richard    Colburn  6198506
# 714          brian.boswell@hines.com          Brian    Boswell  6164675
#
#                          Chapter name  ...  \
# 0          IREM West Michigan Chapter  ...
# 1     IREM Western Washington Chapter  ...
# 2      IREM Greater Nashville Chapter  ...
# 3          IREM Orange County Chapter  ...
# 4    IREM Boston Metropolitan Chapter  ...
# ..                                ...  ...
# 710        IREM South Florida Chapter  ...
# 711         IREM Indianapolis Chapter  ...
# 712  IREM Boston Metropolitan Chapter  ...
# 713  IREM Boston Metropolitan Chapter  ...
# 714              IREM Houston Chapter  ...
#
#     Which of the following best describes your race or ethnicity? (please select all that apply) - Hispanic / Latinx  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 710                                                NaN
# 711                                                NaN
# 712                                                NaN
# 713                                                NaN
# 714                                                NaN
#
#     Which of the following best describes your race or ethnicity? (please select all that apply) - Middle Eastern / North African  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 710                                                NaN
# 711                                                NaN
# 712                                                NaN
# 713                                                NaN
# 714                                                NaN
#
#     Which of the following best describes your race or ethnicity? (please select all that apply) - South Asian  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 710                                                NaN
# 711                                                NaN
# 712                                                NaN
# 713                                                NaN
# 714                                                NaN
#
#     Which of the following best describes your race or ethnicity? (please select all that apply) - White/European American  \
# 0                                                  NaN
# 1                                                  NaN
# 2                              White/European American
# 3                              White/European American
# 4                                                  NaN
# ..                                                 ...
# 710                            White/European American
# 711                            White/European American
# 712                                                NaN
# 713                                                NaN
# 714                                                NaN
#
#     Which of the following best describes your race or ethnicity? (please select all that apply) - A racial/ethnic identity not listed here (please specify)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 710                                                NaN
# 711                                                NaN
# 712                                                NaN
# 713                                                NaN
# 714                                                NaN
#
#     Which of the following best describes your sexual orientation? - Response  \
# 0                                         Heterosexual
# 1                                                  NaN
# 2                                                  NaN
# 3                                         Heterosexual
# 4                                                  NaN
# ..                                                 ...
# 710                                       Heterosexual
# 711                                                Gay
# 712                                                NaN
# 713                                Prefer not to share
# 714                                                NaN
#
#     Which of the following best describes your sexual orientation? - A sexual identity not listed here (please specify)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 710                                                NaN
# 711                                                NaN
# 712                                                NaN
# 713                                                NaN
# 714                                                NaN
#
#     Do you consider yourself to have a disability that includes a physical, mental, and/or medical condition? - Response  \
# 0                                                   No
# 1                                                  NaN
# 2                                                  NaN
# 3                                                   No
# 4                                                  NaN
# ..                                                 ...
# 710                                                 No
# 711                                                Yes
# 712                                                NaN
# 713                                Prefer not to share
# 714                                                NaN
#
#     Not counting any professional certifications, what is your highest level of education? - Response  \
# 0                                    Bachelor's degree
# 1                                                  NaN
# 2                                    Bachelor's degree
# 3                                    Bachelor's degree
# 4                                                  NaN
# ..                                                 ...
# 710                                  Bachelor's degree
# 711                                  Bachelor's degree
# 712                                                NaN
# 713                                  Bachelor's degree
# 714                                                NaN
#
#     Not counting any professional certifications, what is your highest level of education? - Other (please specify)
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 710                                                NaN
# 711                                                NaN
# 712                                                NaN
# 713                                                NaN
# 714                                                NaN
#
# [715 rows x 62 columns]

# %%
dataset_modified = dataset.copy()
dataset_modified
# Out:
#      Respondent ID  Collector ID    Start Date      End Date      IP Address  \
# 0     114254911214     424609639  44982.604132  44982.608380    174.209.41.5
# 1     114254784991     424609561  44982.392211  44982.394120    50.47.84.103
# 2     114254561357     424609639  44981.985521  44981.999062  108.197.66.112
# 3     114254177232     424609639  44981.544699  44981.548125  44.232.201.254
# 4     114253615503     424609561  44980.941007  44980.942616   216.195.4.101
# ..             ...           ...           ...           ...             ...
# 710   114239075355     424609561  44964.377975  44964.381123   173.12.119.74
# 711   114239072831     424609561  44964.376366  44964.380694    74.129.41.54
# 712   114239074004     424609561  44964.376100  44964.378368  50.247.195.142
# 713   114239073171     424609561  44964.376076  44964.378287   100.38.84.227
# 714   114239073402     424609561  44964.377211  44964.377731  216.74.243.186
#
#                        Email Address     First Name  Last Name  IREM ID  \
# 0        CharisseStewart28@gmail.com       Charisse    Stewart  6316678
# 1          robertbalaceanu@gmail.com  Iulian Robert  Balaceanu  6195193
# 2             Crystalstude@yahoo.com        Crystal      Stude  6163848
# 3          bmchenry@riverrockreg.com        Brianna    McHenry   244729
# 4               sarah.berry@live.com          Sarah      Berry  6192377
# ..                               ...            ...        ...      ...
# 710          afortini@tedglasrud.com          Angel    Fortini  6354446
# 711  delawaretracemanager@pedcor.net       Jonathan    Kilgore  6254034
# 712         charvey@corcoranmgmt.com       Caroline     Harvey  6303253
# 713           rcolburn@reliantrs.com        Richard    Colburn  6198506
# 714          brian.boswell@hines.com          Brian    Boswell  6164675
#
#                          Chapter name  ...  \
# 0          IREM West Michigan Chapter  ...
# 1     IREM Western Washington Chapter  ...
# 2      IREM Greater Nashville Chapter  ...
# 3          IREM Orange County Chapter  ...
# 4    IREM Boston Metropolitan Chapter  ...
# ..                                ...  ...
# 710        IREM South Florida Chapter  ...
# 711         IREM Indianapolis Chapter  ...
# 712  IREM Boston Metropolitan Chapter  ...
# 713  IREM Boston Metropolitan Chapter  ...
# 714              IREM Houston Chapter  ...
#
#     Which of the following best describes your race or ethnicity? (please select all that apply) - Hispanic / Latinx  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 710                                                NaN
# 711                                                NaN
# 712                                                NaN
# 713                                                NaN
# 714                                                NaN
#
#     Which of the following best describes your race or ethnicity? (please select all that apply) - Middle Eastern / North African  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 710                                                NaN
# 711                                                NaN
# 712                                                NaN
# 713                                                NaN
# 714                                                NaN
#
#     Which of the following best describes your race or ethnicity? (please select all that apply) - South Asian  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 710                                                NaN
# 711                                                NaN
# 712                                                NaN
# 713                                                NaN
# 714                                                NaN
#
#     Which of the following best describes your race or ethnicity? (please select all that apply) - White/European American  \
# 0                                                  NaN
# 1                                                  NaN
# 2                              White/European American
# 3                              White/European American
# 4                                                  NaN
# ..                                                 ...
# 710                            White/European American
# 711                            White/European American
# 712                                                NaN
# 713                                                NaN
# 714                                                NaN
#
#     Which of the following best describes your race or ethnicity? (please select all that apply) - A racial/ethnic identity not listed here (please specify)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 710                                                NaN
# 711                                                NaN
# 712                                                NaN
# 713                                                NaN
# 714                                                NaN
#
#     Which of the following best describes your sexual orientation? - Response  \
# 0                                         Heterosexual
# 1                                                  NaN
# 2                                                  NaN
# 3                                         Heterosexual
# 4                                                  NaN
# ..                                                 ...
# 710                                       Heterosexual
# 711                                                Gay
# 712                                                NaN
# 713                                Prefer not to share
# 714                                                NaN
#
#     Which of the following best describes your sexual orientation? - A sexual identity not listed here (please specify)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 710                                                NaN
# 711                                                NaN
# 712                                                NaN
# 713                                                NaN
# 714                                                NaN
#
#     Do you consider yourself to have a disability that includes a physical, mental, and/or medical condition? - Response  \
# 0                                                   No
# 1                                                  NaN
# 2                                                  NaN
# 3                                                   No
# 4                                                  NaN
# ..                                                 ...
# 710                                                 No
# 711                                                Yes
# 712                                                NaN
# 713                                Prefer not to share
# 714                                                NaN
#
#     Not counting any professional certifications, what is your highest level of education? - Response  \
# 0                                    Bachelor's degree
# 1                                                  NaN
# 2                                    Bachelor's degree
# 3                                    Bachelor's degree
# 4                                                  NaN
# ..                                                 ...
# 710                                  Bachelor's degree
# 711                                  Bachelor's degree
# 712                                                NaN
# 713                                  Bachelor's degree
# 714                                                NaN
#
#     Not counting any professional certifications, what is your highest level of education? - Other (please specify)
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 710                                                NaN
# 711                                                NaN
# 712                                                NaN
# 713                                                NaN
# 714                                                NaN
#
# [715 rows x 62 columns]

# %%
dataset_modified.columns
# Out:
# Index(['Respondent ID', 'Collector ID', 'Start Date', 'End Date', 'IP Address',
#        'Email Address', 'First Name', 'Last Name', 'IREM ID', 'Chapter name',
#        'Member Status', 'State', 'ZIP Code', 'Country',
#        'What kinds of DEI-related training have you or your employer paid for in the last year? - I'm not sure, or we have not paid for DEI-related training in the last year',
#        'What kinds of DEI-related training have you or your employer paid for in the last year? - Speaker(s) for a DEI event, such as Black History Month, etc.',
#        'What kinds of DEI-related training have you or your employer paid for in the last year? - Consultant for issues related to corporate climate or culture',
#        'What kinds of DEI-related training have you or your employer paid for in the last year? - DEI training or continuing education',
#        'What kinds of DEI-related training have you or your employer paid for in the last year? - Other (please specify)',
#        'How much of a priority do you believe the following DEI topics should be to IREM? - Ensuring IREM governance committees & advisory councils are as inclusive as possible',
#        'How much of a priority do you believe the following DEI topics should be to IREM? - General DEI training on awareness and unconscious bias for regional, national, and international IREM leaders',
#        'How much of a priority do you believe the following DEI topics should be to IREM? - Increasing access to IREM and the broader profession of real estate management for all people, especially historically marginalized groups (i.e., people of color, LGBTQ+ communities, people with disabilities, etc.)',
#        'How much of a priority do you believe the following DEI topics should be to IREM? - Networking, education, and community-building experiences for special interest groups(e.g., DEI reception at Global Summit)',
#        'How much of a priority do you believe the following DEI topics should be to IREM? - Outreach to educational organizations such as HBCUs, high schools, etc.',
#        'How much of a priority do you believe the following DEI topics should be to IREM? - Diverse representation and best hiring practices for individuals and organizations',
#        'Are there other topics you think should be a priority, but that were not listed here? - Open-Ended Response',
#        'Have you attended at least one chapter event in the past year? - Response',
#        'How much of a priority do you think the following DEI topics should be for IREM Chapters? - General DEI training for chapter members and chapter leaders on DEI awareness and building inclusive communities',
#        'How much of a priority do you think the following DEI topics should be for IREM Chapters? - Developing DEI Committees within chapters - defining their purpose, structure, and strategy',
#        'How much of a priority do you think the following DEI topics should be for IREM Chapters? - Content toolkits for Chapters (e.g., social media posts for Black History Month or LGBTQ Pride Month)',
#        'Are there other topics you think should be a priority for DEI as it relates to Chapters, but were not listed here? - Open-Ended Response',
#        'What would you say is the biggest challenge IREM faces, related to diversity, equity, and inclusion? This could be IREM in general, or a specific chapter. - Open-Ended Response',
#        'What would you say IREM has done well in recent years, as it relates to diversity, equity, and inclusion? - Open-Ended Response',
#        'If you could immediately change one thing about IREM as it relates to diversity, equity, and inclusion, what would it be? - Open-Ended Response',
#        'Is there anything else you’d like us to know? - Open-Ended Response',
#        'Please select all the ways you engage with IREM - None of the above',
#        'Please select all the ways you engage with IREM - Enrolled in at least one course or webinar in the past year',
#        'Please select all the ways you engage with IREM - Attended at least one national event in the past year',
#        'Please select all the ways you engage with IREM - Volunteered on an IREM standing committee, advisory council, or ethics panel either currently or in the last year',
#        'Please select all the ways you engage with IREM - Served as a Governing Councilor/RVP/IREM Board of Director either currently or in the last year',
#        'Please select all the ways you engage with IREM - Served as a Chapter Officer, either currently or in the past year',
#        'Please select all the ways you engage with IREM - Currently pursuing an individual certification (i.e., ARM, ACoM, or CPM)',
#        'Please select all the ways you engage with IREM - Employed by an AMO organization',
#        'Please select all the ways you engage with IREM - Served as an IAE currently or in the past year',
#        'Please select all the ways you engage with IREM - Engaged in another way not listed here (please specify)',
#        'About how many years have you worked in the Real Estate Management field? - Response',
#        'Which of the following best describes your gender identity? - Response',
#        'Which of the following best describes your gender identity? - A gender not listed here (please specify)',
#        'Which of the following best describes your race or ethnicity? (please select all that apply) - Prefer not to share',
#        'Which of the following best describes your race or ethnicity? (please select all that apply) - American Indian / Alaskan Native / First Nation / Indigenous',
#        'Which of the following best describes your race or ethnicity? (please select all that apply) - Asian-American / Hawaiian Native / Pacific Islander',
#        'Which of the following best describes your race or ethnicity? (please select all that apply) - Black / African American',
#        'Which of the following best describes your race or ethnicity? (please select all that apply) - Hispanic / Latinx',
#        'Which of the following best describes your race or ethnicity? (please select all that apply) - Middle Eastern / North African',
#        'Which of the following best describes your race or ethnicity? (please select all that apply) - South Asian',
#        'Which of the following best describes your race or ethnicity? (please select all that apply) - White/European American',
#        'Which of the following best describes your race or ethnicity? (please select all that apply) - A racial/ethnic identity not listed here (please specify)',
#        'Which of the following best describes your sexual orientation? - Response',
#        'Which of the following best describes your sexual orientation? - A sexual identity not listed here (please specify)',
#        'Do you consider yourself to have a disability that includes a physical, mental, and/or medical condition? - Response',
#        'Not counting any professional certifications, what is your highest level of education? - Response',
#        'Not counting any professional certifications, what is your highest level of education? - Other (please specify)'],
#       dtype='object')

# %%
columns_to_drop = ['Collector ID', 'Start Date', 'End Date', 'IP Address', 'Email Address', 'First Name', 'Last Name', 'IREM ID', 'ZIP Code', 'Country']
columns_to_drop
# Out:
# ['Collector ID',
#  'Start Date',
#  'End Date',
#  'IP Address',
#  'Email Address',
#  'First Name',
#  'Last Name',
#  'IREM ID',
#  'ZIP Code',
#  'Country']

# %%
dataset_modified = dataset_modified.drop(columns=columns_to_drop)
dataset_modified
# Out:
#      Respondent ID                      Chapter name    Member Status State  \
# 0     114254911214        IREM West Michigan Chapter  CPMCANDIDATE_US    MI
# 1     114254784991   IREM Western Washington Chapter           ARM_US    WA
# 2     114254561357    IREM Greater Nashville Chapter           CPM_US    TN
# 3     114254177232        IREM Orange County Chapter           CPM_US    CA
# 4     114253615503  IREM Boston Metropolitan Chapter           CPM_US    MA
# ..             ...                               ...              ...   ...
# 710   114239075355        IREM South Florida Chapter         ASSOC_US    FL
# 711   114239072831         IREM Indianapolis Chapter           ARM_US    IN
# 712   114239074004  IREM Boston Metropolitan Chapter           ARM_US    MA
# 713   114239073171  IREM Boston Metropolitan Chapter           CPM_US    MA
# 714   114239073402              IREM Houston Chapter  CPMCANDIDATE_US    TX
#
#     What kinds of DEI-related training have you or your employer paid for in the last year? - I'm not sure, or we have not paid for DEI-related training in the last year  \
# 0                                                  NaN
# 1    I'm not sure, or we have not paid for DEI-rela...
# 2    I'm not sure, or we have not paid for DEI-rela...
# 3                                                  NaN
# 4    I'm not sure, or we have not paid for DEI-rela...
# ..                                                 ...
# 710                                                NaN
# 711  I'm not sure, or we have not paid for DEI-rela...
# 712                                                NaN
# 713  I'm not sure, or we have not paid for DEI-rela...
# 714                                                NaN
#
#     What kinds of DEI-related training have you or your employer paid for in the last year? - Speaker(s) for a DEI event, such as Black History Month, etc.  \
# 0    Speaker(s) for a DEI event, such as Black Hist...
# 1                                                  NaN
# 2                                                  NaN
# 3    Speaker(s) for a DEI event, such as Black Hist...
# 4                                                  NaN
# ..                                                 ...
# 710                                                NaN
# 711                                                NaN
# 712  Speaker(s) for a DEI event, such as Black Hist...
# 713                                                NaN
# 714                                                NaN
#
#     What kinds of DEI-related training have you or your employer paid for in the last year? - Consultant for issues related to corporate climate or culture  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 710                                                NaN
# 711                                                NaN
# 712  Consultant for issues related to corporate cli...
# 713                                                NaN
# 714                                                NaN
#
#     What kinds of DEI-related training have you or your employer paid for in the last year? - DEI training or continuing education  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                 DEI training or continuing education
# 4                                                  NaN
# ..                                                 ...
# 710               DEI training or continuing education
# 711                                                NaN
# 712               DEI training or continuing education
# 713                                                NaN
# 714               DEI training or continuing education
#
#     What kinds of DEI-related training have you or your employer paid for in the last year? - Other (please specify)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 710                                                NaN
# 711                                                NaN
# 712                                                NaN
# 713                                                NaN
# 714                                                NaN
#
#     How much of a priority do you believe the following DEI topics should be to IREM? - Ensuring IREM governance committees & advisory councils are as inclusive as possible  \
# 0                                       Very important
# 1                                       Very important
# 2                                 Not important at all
# 3                                       Very important
# 4                                       Very important
# ..                                                 ...
# 710                                     Very important
# 711                                     Most important
# 712                                       I don't know
# 713                                  Not too important
# 714                                     Very important
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 710  ...
# 711  ...
# 712  ...
# 713  ...
# 714  ...
#
#     Which of the following best describes your race or ethnicity? (please select all that apply) - Hispanic / Latinx  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 710                                                NaN
# 711                                                NaN
# 712                                                NaN
# 713                                                NaN
# 714                                                NaN
#
#     Which of the following best describes your race or ethnicity? (please select all that apply) - Middle Eastern / North African  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 710                                                NaN
# 711                                                NaN
# 712                                                NaN
# 713                                                NaN
# 714                                                NaN
#
#     Which of the following best describes your race or ethnicity? (please select all that apply) - South Asian  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 710                                                NaN
# 711                                                NaN
# 712                                                NaN
# 713                                                NaN
# 714                                                NaN
#
#     Which of the following best describes your race or ethnicity? (please select all that apply) - White/European American  \
# 0                                                  NaN
# 1                                                  NaN
# 2                              White/European American
# 3                              White/European American
# 4                                                  NaN
# ..                                                 ...
# 710                            White/European American
# 711                            White/European American
# 712                                                NaN
# 713                                                NaN
# 714                                                NaN
#
#     Which of the following best describes your race or ethnicity? (please select all that apply) - A racial/ethnic identity not listed here (please specify)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 710                                                NaN
# 711                                                NaN
# 712                                                NaN
# 713                                                NaN
# 714                                                NaN
#
#     Which of the following best describes your sexual orientation? - Response  \
# 0                                         Heterosexual
# 1                                                  NaN
# 2                                                  NaN
# 3                                         Heterosexual
# 4                                                  NaN
# ..                                                 ...
# 710                                       Heterosexual
# 711                                                Gay
# 712                                                NaN
# 713                                Prefer not to share
# 714                                                NaN
#
#     Which of the following best describes your sexual orientation? - A sexual identity not listed here (please specify)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 710                                                NaN
# 711                                                NaN
# 712                                                NaN
# 713                                                NaN
# 714                                                NaN
#
#     Do you consider yourself to have a disability that includes a physical, mental, and/or medical condition? - Response  \
# 0                                                   No
# 1                                                  NaN
# 2                                                  NaN
# 3                                                   No
# 4                                                  NaN
# ..                                                 ...
# 710                                                 No
# 711                                                Yes
# 712                                                NaN
# 713                                Prefer not to share
# 714                                                NaN
#
#     Not counting any professional certifications, what is your highest level of education? - Response  \
# 0                                    Bachelor's degree
# 1                                                  NaN
# 2                                    Bachelor's degree
# 3                                    Bachelor's degree
# 4                                                  NaN
# ..                                                 ...
# 710                                  Bachelor's degree
# 711                                  Bachelor's degree
# 712                                                NaN
# 713                                  Bachelor's degree
# 714                                                NaN
#
#     Not counting any professional certifications, what is your highest level of education? - Other (please specify)
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 710                                                NaN
# 711                                                NaN
# 712                                                NaN
# 713                                                NaN
# 714                                                NaN
#
# [715 rows x 52 columns]

# %%
id_vars = list(dataset_modified.columns)[0:4]
value_vars = list(dataset_modified.columns)[4:]
# value_vars

# %%
dataset_melted = dataset_modified.melt(id_vars=id_vars, value_vars=value_vars, var_name='Question + Subquestion', value_name='Answer')
# dataset_melted

# %%
questions_import = pd.read_excel(pwd + '/2023 DEI Survey - Edited.xlsx', sheet_name='Question')
questions_import
# Out:
#                                          Raw Question  \
# 0                                       Respondent ID
# 1                                        Collector ID
# 2                                          Start Date
# 3                                            End Date
# 4                                          IP Address
# ..                                                ...
# 57  Which of the following best describes your sex...
# 58                                                NaN
# 59  Do you consider yourself to have a disability ...
# 60  Not counting any professional certifications, ...
# 61                                                NaN
#
#                                       Raw Subquestion  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 57                                           Response
# 58  A sexual identity not listed here (please spec...
# 59                                           Response
# 60                                           Response
# 61                             Other (please specify)
#
#                                              Question  \
# 0                                       Respondent ID
# 1                                        Collector ID
# 2                                          Start Date
# 3                                            End Date
# 4                                          IP Address
# ..                                                ...
# 57  Which of the following best describes your sex...
# 58  Which of the following best describes your sex...
# 59  Do you consider yourself to have a disability ...
# 60  Not counting any professional certifications, ...
# 61  Not counting any professional certifications, ...
#
#                                           Subquestion  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 57                                           Response
# 58  A sexual identity not listed here (please spec...
# 59                                           Response
# 60                                           Response
# 61                             Other (please specify)
#
#                                Question + Subquestion
# 0                                       Respondent ID
# 1                                        Collector ID
# 2                                          Start Date
# 3                                            End Date
# 4                                          IP Address
# ..                                                ...
# 57  Which of the following best describes your sex...
# 58  Which of the following best describes your sex...
# 59  Do you consider yourself to have a disability ...
# 60  Not counting any professional certifications, ...
# 61  Not counting any professional certifications, ...
#
# [62 rows x 5 columns]

# %%
questions = questions_import.copy()
questions.drop(columns=['Raw Question', 'Raw Subquestion', 'Subquestion'], inplace=True)

# %%
questions
# Out:
#                                              Question  \
# 0                                       Respondent ID
# 1                                        Collector ID
# 2                                          Start Date
# 3                                            End Date
# 4                                          IP Address
# ..                                                ...
# 57  Which of the following best describes your sex...
# 58  Which of the following best describes your sex...
# 59  Do you consider yourself to have a disability ...
# 60  Not counting any professional certifications, ...
# 61  Not counting any professional certifications, ...
#
#                                Question + Subquestion
# 0                                       Respondent ID
# 1                                        Collector ID
# 2                                          Start Date
# 3                                            End Date
# 4                                          IP Address
# ..                                                ...
# 57  Which of the following best describes your sex...
# 58  Which of the following best describes your sex...
# 59  Do you consider yourself to have a disability ...
# 60  Not counting any professional certifications, ...
# 61  Not counting any professional certifications, ...
#
# [62 rows x 2 columns]

# %%
questions.dropna(inplace=True)

# %%
questions
# Out:
#                                              Question  \
# 0                                       Respondent ID
# 1                                        Collector ID
# 2                                          Start Date
# 3                                            End Date
# 4                                          IP Address
# ..                                                ...
# 57  Which of the following best describes your sex...
# 58  Which of the following best describes your sex...
# 59  Do you consider yourself to have a disability ...
# 60  Not counting any professional certifications, ...
# 61  Not counting any professional certifications, ...
#
#                                Question + Subquestion
# 0                                       Respondent ID
# 1                                        Collector ID
# 2                                          Start Date
# 3                                            End Date
# 4                                          IP Address
# ..                                                ...
# 57  Which of the following best describes your sex...
# 58  Which of the following best describes your sex...
# 59  Do you consider yourself to have a disability ...
# 60  Not counting any professional certifications, ...
# 61  Not counting any professional certifications, ...
#
# [62 rows x 2 columns]

# %%
dataset_merged = pd.merge(left=dataset_melted, right=questions, how='left', left_on='Question + Subquestion', right_on='Question + Subquestion')
# print(dataset_merged.shape)
print("Original Data", len(dataset_melted))
print("Merged Data", len(dataset_merged))
dataset_merged
# Out:
# Original Data 34320
# Merged Data 34320
#        Respondent ID                      Chapter name    Member Status State  \
# 0       114254911214        IREM West Michigan Chapter  CPMCANDIDATE_US    MI
# 1       114254784991   IREM Western Washington Chapter           ARM_US    WA
# 2       114254561357    IREM Greater Nashville Chapter           CPM_US    TN
# 3       114254177232        IREM Orange County Chapter           CPM_US    CA
# 4       114253615503  IREM Boston Metropolitan Chapter           CPM_US    MA
# ...              ...                               ...              ...   ...
# 34315   114239075355        IREM South Florida Chapter         ASSOC_US    FL
# 34316   114239072831         IREM Indianapolis Chapter           ARM_US    IN
# 34317   114239074004  IREM Boston Metropolitan Chapter           ARM_US    MA
# 34318   114239073171  IREM Boston Metropolitan Chapter           CPM_US    MA
# 34319   114239073402              IREM Houston Chapter  CPMCANDIDATE_US    TX
#
#                                   Question + Subquestion  \
# 0      What kinds of DEI-related training have you or...
# 1      What kinds of DEI-related training have you or...
# 2      What kinds of DEI-related training have you or...
# 3      What kinds of DEI-related training have you or...
# 4      What kinds of DEI-related training have you or...
# ...                                                  ...
# 34315  Not counting any professional certifications, ...
# 34316  Not counting any professional certifications, ...
# 34317  Not counting any professional certifications, ...
# 34318  Not counting any professional certifications, ...
# 34319  Not counting any professional certifications, ...
#
#                                                   Answer  \
# 0                                                    NaN
# 1      I'm not sure, or we have not paid for DEI-rela...
# 2      I'm not sure, or we have not paid for DEI-rela...
# 3                                                    NaN
# 4      I'm not sure, or we have not paid for DEI-rela...
# ...                                                  ...
# 34315                                                NaN
# 34316                                                NaN
# 34317                                                NaN
# 34318                                                NaN
# 34319                                                NaN
#
#                                                 Question
# 0      What kinds of DEI-related training have you or...
# 1      What kinds of DEI-related training have you or...
# 2      What kinds of DEI-related training have you or...
# 3      What kinds of DEI-related training have you or...
# 4      What kinds of DEI-related training have you or...
# ...                                                  ...
# 34315  Not counting any professional certifications, ...
# 34316  Not counting any professional certifications, ...
# 34317  Not counting any professional certifications, ...
# 34318  Not counting any professional certifications, ...
# 34319  Not counting any professional certifications, ...
#
# [34320 rows x 7 columns]

# %%
respondents = dataset_merged[dataset_merged["Answer"].notna()]
respondents = respondents.groupby("Question")["Respondent ID"].nunique().reset_index()
respondents.rename(columns={"Respondent ID": "Respondents"}, inplace=True)
respondents
# Out:
#                                              Question  Respondents
# 0   About how many years have you worked in the Re...          599
# 1   Are there other topics you think should be a p...           60
# 2   Are there other topics you think should be a p...          111
# 3   Do you consider yourself to have a disability ...          587
# 4   Have you attended at least one chapter event i...          711
# 5   How much of a priority do you believe the foll...          712
# 6   How much of a priority do you think the follow...          461
# 7   If you could immediately change one thing abou...          256
# 8       Is there anything else you’d like us to know?          146
# 9   Not counting any professional certifications, ...          594
# 10    Please select all the ways you engage with IREM          587
# 11  What kinds of DEI-related training have you or...          704
# 12  What would you say IREM has done well in recen...          316
# 13  What would you say is the biggest challenge IR...          334
# 14  Which of the following best describes your gen...          597
# 15  Which of the following best describes your rac...          597
# 16  Which of the following best describes your sex...          587

# %%
dataset_merged_two = pd.merge(left=dataset_merged, right=respondents, how='left', left_on='Question', right_on='Question')
# print(dataset_merged.shape)
print("Original Data", len(dataset_melted))
print("Merged Data", len(dataset_merged))
dataset_merged_two
# Out:
# Original Data 34320
# Merged Data 34320
#        Respondent ID                      Chapter name    Member Status State  \
# 0       114254911214        IREM West Michigan Chapter  CPMCANDIDATE_US    MI
# 1       114254784991   IREM Western Washington Chapter           ARM_US    WA
# 2       114254561357    IREM Greater Nashville Chapter           CPM_US    TN
# 3       114254177232        IREM Orange County Chapter           CPM_US    CA
# 4       114253615503  IREM Boston Metropolitan Chapter           CPM_US    MA
# ...              ...                               ...              ...   ...
# 34315   114239075355        IREM South Florida Chapter         ASSOC_US    FL
# 34316   114239072831         IREM Indianapolis Chapter           ARM_US    IN
# 34317   114239074004  IREM Boston Metropolitan Chapter           ARM_US    MA
# 34318   114239073171  IREM Boston Metropolitan Chapter           CPM_US    MA
# 34319   114239073402              IREM Houston Chapter  CPMCANDIDATE_US    TX
#
#                                   Question + Subquestion  \
# 0      What kinds of DEI-related training have you or...
# 1      What kinds of DEI-related training have you or...
# 2      What kinds of DEI-related training have you or...
# 3      What kinds of DEI-related training have you or...
# 4      What kinds of DEI-related training have you or...
# ...                                                  ...
# 34315  Not counting any professional certifications, ...
# 34316  Not counting any professional certifications, ...
# 34317  Not counting any professional certifications, ...
# 34318  Not counting any professional certifications, ...
# 34319  Not counting any professional certifications, ...
#
#                                                   Answer  \
# 0                                                    NaN
# 1      I'm not sure, or we have not paid for DEI-rela...
# 2      I'm not sure, or we have not paid for DEI-rela...
# 3                                                    NaN
# 4      I'm not sure, or we have not paid for DEI-rela...
# ...                                                  ...
# 34315                                                NaN
# 34316                                                NaN
# 34317                                                NaN
# 34318                                                NaN
# 34319                                                NaN
#
#                                                 Question  Respondents
# 0      What kinds of DEI-related training have you or...          704
# 1      What kinds of DEI-related training have you or...          704
# 2      What kinds of DEI-related training have you or...          704
# 3      What kinds of DEI-related training have you or...          704
# 4      What kinds of DEI-related training have you or...          704
# ...                                                  ...          ...
# 34315  Not counting any professional certifications, ...          594
# 34316  Not counting any professional certifications, ...          594
# 34317  Not counting any professional certifications, ...          594
# 34318  Not counting any professional certifications, ...          594
# 34319  Not counting any professional certifications, ...          594
#
# [34320 rows x 8 columns]

# %%
same_answer = dataset_merged # [dataset_merged["Answer"].notna()]
same_answer = same_answer.groupby(["Question + Subquestion", "Answer"])["Respondent ID"].nunique().reset_index()
same_answer.rename(columns={"Respondent ID":"Same Answer"}, inplace=True)
same_answer
# Out:
#                                  Question + Subquestion               Answer  \
# 0     About how many years have you worked in the Re...          1 – 5 years
# 1     About how many years have you worked in the Re...        11 – 20 years
# 2     About how many years have you worked in the Re...         6 – 10 years
# 3     About how many years have you worked in the Re...     Less than a year
# 4     About how many years have you worked in the Re...   More than 20 years
# ...                                                 ...                  ...
# 1436  Which of the following best describes your sex...              Lesbian
# 1437  Which of the following best describes your sex...            Pansexual
# 1438  Which of the following best describes your sex...  Prefer not to share
# 1439  Which of the following best describes your sex...                Queer
# 1440  Which of the following best describes your sex...          Questioning
#
#       Same Answer
# 0              46
# 1             149
# 2              94
# 3               9
# 4             301
# ...           ...
# 1436            6
# 1437            1
# 1438           70
# 1439            5
# 1440            1
#
# [1441 rows x 3 columns]

# %%
dataset_merged_three = pd.merge(left=dataset_merged_two, right=same_answer, how='left', left_on=['Question + Subquestion', 'Answer'], right_on=['Question + Subquestion', 'Answer'])
dataset_merged_three['Same Answer'].fillna(0, inplace=True)
# print(dataset_merged.shape)
print("Original Data", len(dataset_merged_two))
print("Merged Data", len(dataset_merged_three))
dataset_merged_three
# Out:
# Original Data 34320
# Merged Data 34320
#        Respondent ID                      Chapter name    Member Status State  \
# 0       114254911214        IREM West Michigan Chapter  CPMCANDIDATE_US    MI
# 1       114254784991   IREM Western Washington Chapter           ARM_US    WA
# 2       114254561357    IREM Greater Nashville Chapter           CPM_US    TN
# 3       114254177232        IREM Orange County Chapter           CPM_US    CA
# 4       114253615503  IREM Boston Metropolitan Chapter           CPM_US    MA
# ...              ...                               ...              ...   ...
# 34315   114239075355        IREM South Florida Chapter         ASSOC_US    FL
# 34316   114239072831         IREM Indianapolis Chapter           ARM_US    IN
# 34317   114239074004  IREM Boston Metropolitan Chapter           ARM_US    MA
# 34318   114239073171  IREM Boston Metropolitan Chapter           CPM_US    MA
# 34319   114239073402              IREM Houston Chapter  CPMCANDIDATE_US    TX
#
#                                   Question + Subquestion  \
# 0      What kinds of DEI-related training have you or...
# 1      What kinds of DEI-related training have you or...
# 2      What kinds of DEI-related training have you or...
# 3      What kinds of DEI-related training have you or...
# 4      What kinds of DEI-related training have you or...
# ...                                                  ...
# 34315  Not counting any professional certifications, ...
# 34316  Not counting any professional certifications, ...
# 34317  Not counting any professional certifications, ...
# 34318  Not counting any professional certifications, ...
# 34319  Not counting any professional certifications, ...
#
#                                                   Answer  \
# 0                                                    NaN
# 1      I'm not sure, or we have not paid for DEI-rela...
# 2      I'm not sure, or we have not paid for DEI-rela...
# 3                                                    NaN
# 4      I'm not sure, or we have not paid for DEI-rela...
# ...                                                  ...
# 34315                                                NaN
# 34316                                                NaN
# 34317                                                NaN
# 34318                                                NaN
# 34319                                                NaN
#
#                                                 Question  Respondents  \
# 0      What kinds of DEI-related training have you or...          704
# 1      What kinds of DEI-related training have you or...          704
# 2      What kinds of DEI-related training have you or...          704
# 3      What kinds of DEI-related training have you or...          704
# 4      What kinds of DEI-related training have you or...          704
# ...                                                  ...          ...
# 34315  Not counting any professional certifications, ...          594
# 34316  Not counting any professional certifications, ...          594
# 34317  Not counting any professional certifications, ...          594
# 34318  Not counting any professional certifications, ...          594
# 34319  Not counting any professional certifications, ...          594
#
#        Same Answer
# 0              0.0
# 1            344.0
# 2            344.0
# 3              0.0
# 4            344.0
# ...            ...
# 34315          0.0
# 34316          0.0
# 34317          0.0
# 34318          0.0
# 34319          0.0
#
# [34320 rows x 9 columns]

# %%
output = dataset_merged_three.copy()

# %%
output.to_excel(pwd + '/2023 DEI Survey - Clean.xlsx', index=False)
